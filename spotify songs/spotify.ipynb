# %%
import pandas as pd
# !kaggle datasets download -d joebeachcapital/30000-spotify-songs
# Out:
# 30000-spotify-songs.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
with zipfile.ZipFile('30000-spotify-songs.zip', 'r') as file:
    file.extractall()

# %%
data = pd.read_csv('spotify_songs.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  object
#  1   track_name                32828 non-null  object
#  2   track_artist              32828 non-null  object
#  3   track_popularity          32833 non-null  int64
#  4   track_album_id            32833 non-null  object
#  5   track_album_name          32828 non-null  object
#  6   track_album_release_date  32833 non-null  object
#  7   playlist_name             32833 non-null  object
#  8   playlist_id               32833 non-null  object
#  9   playlist_genre            32833 non-null  object
#  10  playlist_subgenre         32833 non-null  object
#  11  danceability              32833 non-null  float64
#  12  energy                    32833 non-null  float64
#  13  key                       32833 non-null  int64
#  14  loudness                  32833 non-null  float64
#  15  mode                      32833 non-null  int64
#  16  speechiness               32833 non-null  float64
#  17  acousticness              32833 non-null  float64
#  18  instrumentalness          32833 non-null  float64
#  19  liveness                  32833 non-null  float64
#  20  valence                   32833 non-null  float64
#  21  tempo                     32833 non-null  float64
#  22  duration_ms               32833 non-null  int64
# dtypes: float64(9), int64(4), object(10)
# memory usage: 5.8+ MB

# %%
data.describe()
# Out:
#        track_popularity  danceability        energy           key  \
# count      32833.000000  32833.000000  32833.000000  32833.000000
# mean          42.477081      0.654850      0.698619      5.374471
# std           24.984074      0.145085      0.180910      3.611657
# min            0.000000      0.000000      0.000175      0.000000
# 25%           24.000000      0.563000      0.581000      2.000000
# 50%           45.000000      0.672000      0.721000      6.000000
# 75%           62.000000      0.761000      0.840000      9.000000
# max          100.000000      0.983000      1.000000     11.000000
#
#            loudness          mode   speechiness  acousticness  \
# count  32833.000000  32833.000000  32833.000000  32833.000000
# mean      -6.719499      0.565711      0.107068      0.175334
# std        2.988436      0.495671      0.101314      0.219633
# min      -46.448000      0.000000      0.000000      0.000000
# 25%       -8.171000      0.000000      0.041000      0.015100
# 50%       -6.166000      1.000000      0.062500      0.080400
# 75%       -4.645000      1.000000      0.132000      0.255000
# max        1.275000      1.000000      0.918000      0.994000
#
#        instrumentalness      liveness       valence         tempo  \
# count      32833.000000  32833.000000  32833.000000  32833.000000
# mean           0.084747      0.190176      0.510561    120.881132
# std            0.224230      0.154317      0.233146     26.903624
# min            0.000000      0.000000      0.000000      0.000000
# 25%            0.000000      0.092700      0.331000     99.960000
# 50%            0.000016      0.127000      0.512000    121.984000
# 75%            0.004830      0.248000      0.693000    133.918000
# max            0.994000      0.996000      0.991000    239.440000
#
#          duration_ms
# count   32833.000000
# mean   225799.811622
# std     59834.006182
# min      4000.000000
# 25%    187819.000000
# 50%    216000.000000
# 75%    253585.000000
# max    517810.000000

# %%
data
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                        Memories - Dillon Francis Remix          Maroon 5
# 2                        All the Time - Don Diablo Remix      Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                  ...               ...
# 32828               City Of Lights - Official Radio Edit      Lush & Simon
# 32829                Closer - Sultan & Ned Shepard Remix    Tegan and Sara
# 32830                       Sweet Surrender - Radio Edit       Starkillers
# 32831                     Only For You - Maor Levi Remix            Mat Zo
# 32832                             Typhoon - Original Mix      Julian Calor
#
#        track_popularity          track_album_id  \
# 0                    66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1                    67  63rPSO264uRjW1X5E6cWv6
# 2                    70  1HoSmj2eLcsrR0vE9gThr4
# 3                    60  1nqYsOef1yKKuGOVchbsk6
# 4                    69  7m7vv9wlQ4i0LFuJiE2zsQ
# ...                 ...                     ...
# 32828                42  2azRoBBWEEEYhqV6sb7JrT
# 32829                20  6kD6KLxj7s8eCE3ABvAyf5
# 32830                14  0ltWNSY9JgxoIZO4VzuCa6
# 32831                15  1fGrOkHnHJcStl14zNx8Jy
# 32832                27  0X3mUOm6MhxR7PzxG95rAo
#
#                                         track_album_name  \
# 0      I Don't Care (with Justin Bieber) [Loud Luxury...
# 1                        Memories (Dillon Francis Remix)
# 2                        All the Time (Don Diablo Remix)
# 3                            Call You Mine - The Remixes
# 4                Someone You Loved (Future Humans Remix)
# ...                                                  ...
# 32828                         City Of Lights (Vocal Mix)
# 32829                                     Closer Remixed
# 32830                       Sweet Surrender (Radio Edit)
# 32831                             Only For You (Remixes)
# 32832                                      Typhoon/Storm
#
#       track_album_release_date    playlist_name             playlist_id  \
# 0                   2019-06-14        Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 1                   2019-12-13        Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 2                   2019-07-05        Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 3                   2019-07-19        Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 4                   2019-03-05        Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# ...                        ...              ...                     ...
# 32828               2014-04-28  ♥ EDM LOVE 2020  6jI1gFr6ANFtT8MmTvA2Ux
# 32829               2013-03-08  ♥ EDM LOVE 2020  6jI1gFr6ANFtT8MmTvA2Ux
# 32830               2014-04-21  ♥ EDM LOVE 2020  6jI1gFr6ANFtT8MmTvA2Ux
# 32831               2014-01-01  ♥ EDM LOVE 2020  6jI1gFr6ANFtT8MmTvA2Ux
# 32832               2014-03-03  ♥ EDM LOVE 2020  6jI1gFr6ANFtT8MmTvA2Ux
#
#       playlist_genre  ... key  loudness  mode  speechiness  acousticness  \
# 0                pop  ...   6    -2.634     1       0.0583      0.102000
# 1                pop  ...  11    -4.969     1       0.0373      0.072400
# 2                pop  ...   1    -3.432     0       0.0742      0.079400
# 3                pop  ...   7    -3.778     1       0.1020      0.028700
# 4                pop  ...   1    -4.672     1       0.0359      0.080300
# ...              ...  ...  ..       ...   ...          ...           ...
# 32828            edm  ...   2    -1.814     1       0.0936      0.076600
# 32829            edm  ...   0    -4.462     1       0.0420      0.001710
# 32830            edm  ...   6    -4.899     0       0.0481      0.108000
# 32831            edm  ...   2    -3.361     1       0.1090      0.007920
# 32832            edm  ...   5    -4.571     0       0.0385      0.000133
#
#        instrumentalness  liveness  valence    tempo  duration_ms
# 0              0.000000    0.0653   0.5180  122.036       194754
# 1              0.004210    0.3570   0.6930   99.972       162600
# 2              0.000023    0.1100   0.6130  124.008       176616
# 3              0.000009    0.2040   0.2770  121.956       169093
# 4              0.000000    0.0833   0.7250  123.976       189052
# ...                 ...       ...      ...      ...          ...
# 32828          0.000000    0.0668   0.2100  128.170       204375
# 32829          0.004270    0.3750   0.4000  128.041       353120
# 32830          0.000001    0.1500   0.4360  127.989       210112
# 32831          0.127000    0.3430   0.3080  128.008       367432
# 32832          0.341000    0.7420   0.0894  127.984       337500
#
# [32833 rows x 23 columns]

# %%
#Artist with the most entries in the data
data.track_artist.mode()
# Out:
# 0    Martin Garrix
# Name: track_artist, dtype: object

# %%
#showing the dataframe for Martin Garrix
data.loc[data.track_artist== 'Martin Garrix']
# Out:
#                      track_id  \
# 14     55nMnifaQWKe3f9cbwOXwx
# 108    1ahVFh0ViDZr8LvkEVlq3B
# 125    4aTtHoSBB0CuQGA6vXBNyp
# 137    3ebXMykcMXOcLeJ9xZ17XH
# 199    7pWK1kMgHy5lNNiIfuRbkP
# ...                       ...
# 32530  1ahVFh0ViDZr8LvkEVlq3B
# 32538  0W6yJKJW8I04iDT6BsINaL
# 32549  5UHrKSQhNs96msAx8LPVwS
# 32551  6lBQ0SMCrJ7zy1LSCuXqwV
# 32562  27YP211Rr8RezhiFVDLFI8
#
#                                               track_name   track_artist  \
# 14     Summer Days (feat. Macklemore & Patrick Stump ...  Martin Garrix
# 108                                No Sleep (feat. Bonn)  Martin Garrix
# 125                                    Home (feat. Bonn)  Martin Garrix
# 137                                  Scared to Be Lonely  Martin Garrix
# 199                       Used To Love (with Dean Lewis)  Martin Garrix
# ...                                                  ...            ...
# 32530                              No Sleep (feat. Bonn)  Martin Garrix
# 32538                              Virus (How About Now)  Martin Garrix
# 32549                                Breach (Walk Alone)  Martin Garrix
# 32551                                  Lions in the Wild  Martin Garrix
# 32562          Waiting For Tomorrow (feat. Mike Shinoda)  Martin Garrix
#
#        track_popularity          track_album_id  \
# 14                   63  2vx3BtBMn8Ed3ygEg1OT2t
# 108                  76  7KJTuTXYSnBGNgAxte3CSg
# 125                  72  1cL51Zp86zgzMDTXRiq8w9
# 137                  81  2v9rQe4F8fVSh5v8bAq0jF
# 199                  83  3YD1qyD9KPFzzTK1UC1Gvo
# ...                 ...                     ...
# 32530                76  7KJTuTXYSnBGNgAxte3CSg
# 32538                43  6cMs1rlzNK7VhFI5zXNXID
# 32549                52  5dv1oLETxdsYOkS2Sic00z
# 32551                57  2x8X4Dq12rXdQsmk41F3VV
# 32562                59  5dv1oLETxdsYOkS2Sic00z
#
#                                         track_album_name  \
# 14     Summer Days (feat. Macklemore & Patrick Stump ...
# 108                                No Sleep (feat. Bonn)
# 125                                    Home (feat. Bonn)
# 137                                  Scared to Be Lonely
# 199                       Used To Love (with Dean Lewis)
# ...                                                  ...
# 32530                              No Sleep (feat. Bonn)
# 32538                              Virus (How About Now)
# 32549                                           BYLAW EP
# 32551                                  Lions in the Wild
# 32562                                           BYLAW EP
#
#       track_album_release_date  \
# 14                  2019-07-12
# 108                 2019-02-21
# 125                 2019-08-16
# 137                 2017-01-27
# 199                 2019-10-31
# ...                        ...
# 32530               2019-02-21
# 32538               2015-02-13
# 32549               2018-10-19
# 32551               2016-05-27
# 32562               2018-10-19
#
#                                            playlist_name  \
# 14                                             Pop Remix
# 108                                            Dance Pop
# 125                                            Dance Pop
# 137                                            Dance Pop
# 199                                           Dance Room
# ...                                                  ...
# 32530  Festival Music 2019 - Warm Up Music (EDM, Big ...
# 32538  Festival Music 2019 - Warm Up Music (EDM, Big ...
# 32549  Festival Music 2019 - Warm Up Music (EDM, Big ...
# 32551  Festival Music 2019 - Warm Up Music (EDM, Big ...
# 32562  Festival Music 2019 - Warm Up Music (EDM, Big ...
#
#                   playlist_id playlist_genre  ... key  loudness  mode  \
# 14     37i9dQZF1DXcZDD7cfEKhW            pop  ...   5    -4.446     0
# 108    37i9dQZF1DWZQaaqNMbbXa            pop  ...  11    -6.385     1
# 125    37i9dQZF1DWZQaaqNMbbXa            pop  ...   8    -4.855     0
# 137    37i9dQZF1DWZQaaqNMbbXa            pop  ...   1    -7.786     0
# 199    37i9dQZF1DX2ENAPP1Tyed            pop  ...   4    -4.722     1
# ...                       ...            ...  ...  ..       ...   ...
# 32530  73uj4YmsC7SJ6SbUMTvf07            edm  ...  11    -6.385     1
# 32538  73uj4YmsC7SJ6SbUMTvf07            edm  ...   5    -6.252     0
# 32549  73uj4YmsC7SJ6SbUMTvf07            edm  ...   1    -4.781     1
# 32551  73uj4YmsC7SJ6SbUMTvf07            edm  ...   7    -6.810     0
# 32562  73uj4YmsC7SJ6SbUMTvf07            edm  ...   5    -4.084     0
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 14          0.0594       0.00733          0.001830    0.0729   0.2380
# 108         0.0326       0.12900          0.000000    0.1210   0.3270
# 125         0.0307       0.06550          0.000004    0.1320   0.2360
# 137         0.0576       0.08950          0.000000    0.2610   0.1950
# 199         0.0375       0.45800          0.000000    0.3350   0.3920
# ...            ...           ...               ...       ...      ...
# 32530       0.0326       0.12900          0.000000    0.1210   0.3270
# 32538       0.0395       0.00121          0.497000    0.8240   0.0801
# 32549       0.2160       0.03880          0.014600    0.2140   0.4830
# 32551       0.0442       0.00434          0.000000    0.8160   0.2800
# 32562       0.1410       0.00731          0.000000    0.5620   0.3360
#
#          tempo  duration_ms
# 14     126.070       255238
# 108    128.133       207095
# 125    128.114       239067
# 137    137.972       220883
# 199    118.970       236765
# ...        ...          ...
# 32530  128.133       207095
# 32538  128.032       198387
# 32549  128.069       178125
# 32551  127.854       211890
# 32562  128.015       247505
#
# [161 rows x 23 columns]

# %%
#find out the average popularity
data.loc[data.track_artist== 'Martin Garrix'].track_popularity.mean()
# Out:
# 47.20496894409938

# %%
#which of his entries are from which album
data.loc[data.track_artist== 'Martin Garrix'].track_album_name.value_counts()
# Out:
# track_album_name
# Animals                                                   6
# Mistaken (feat. Alex Aris)                                6
# High On Life (feat. Bonn)                                 6
# Virus (How About Now)                                     6
# No Sleep (feat. Bonn)                                     6
#                                                          ..
# Animals (The Remixes Part 1)                              1
# Proxy                                                     1
# Spinnin' Records ADE 2013 (Amsterdam Dance Event 2013)    1
# Ocean (feat. Khalid) [David Guetta Remix]                 1
# Latency                                                   1
# Name: count, Length: 61, dtype: int64

# %%
#generating the most common artists
data.track_artist.value_counts()
# Out:
# track_artist
# Martin Garrix       161
# Queen               136
# The Chainsmokers    123
# David Guetta        110
# Don Omar            102
#                    ...
# Underworld            1
# The Witches           1
# Tess Parks            1
# Mick Harvey           1
# Mat Zo                1
# Name: count, Length: 10692, dtype: int64

# %%
#analyzing the genre with the most entries
genre = data['playlist_genre'].value_counts()
genre
# Out:
# playlist_genre
# edm      6043
# rap      5746
# pop      5507
# r&b      5431
# latin    5155
# rock     4951
# Name: count, dtype: int64

# %%
genre.index
# Out:
# Index(['edm', 'rap', 'pop', 'r&b', 'latin', 'rock'], dtype='object', name='playlist_genre')

# %%
#generating a pie 
genre.plot.pie(autopct= "%1.0f%%", colormap= 'plasma')
plt.title('Total Songs in each Genre')
plt.show()

# %% [markdown]
# HYPOTHESIS 1: POP IS THE MOST POPULAR GENRE

# %%
#creating a list to use as an dataframe later
output = []
for x in genre.index:
    genpop = data.loc[data.playlist_genre == x].track_popularity.mean()
    output.append([x,genpop])

# %%
#testing if the list works
output
# Out:
# [['edm', 34.83352639417508],
#  ['rap', 43.21545422902889],
#  ['pop', 47.74487016524424],
#  ['r&b', 41.22353157797827],
#  ['latin', 47.026576139670226],
#  ['rock', 41.72833770955363]]

# %%
#creating a new dataframe
genre_popularity_df = pd.DataFrame(output, columns=['Genre', 'average_popularity'])
genre_popularity_df
# Out:
#    Genre  average_popularity
# 0    edm           34.833526
# 1    rap           43.215454
# 2    pop           47.744870
# 3    r&b           41.223532
# 4  latin           47.026576
# 5   rock           41.728338

# %%
#change the scale in average_popularity to 0-1
genre_popularity_df.average_popularity = genre_popularity_df.average_popularity/genre_popularity_df.average_popularity.max()
genre_popularity_df
# Out:
#    Genre  average_popularity
# 0    edm            0.729576
# 1    rap            0.905133
# 2    pop            1.000000
# 3    r&b            0.863413
# 4  latin            0.984956
# 5   rock            0.873986

# %%
genre_popularity_df.plot(x='Genre', kind='bar', legend= False, ylabel='Popularity from 0-1')
plt.title('Most popular Genres')
plt.show()

# %% [markdown]
# As we can see: The most popular genre is actually pop music followed by latin music. The least popular genre is edm music.

# %% [markdown]
# HYPOTHESIS 2: TRACK POPULARITY CORRELATES TO DANCEABILITY

# %%
# only selecting the numeric values
numvalues = data.select_dtypes(include=['float64', 'int64'])
numvalues
# Out:
#        track_popularity  danceability  energy  key  loudness  mode  \
# 0                    66         0.748   0.916    6    -2.634     1
# 1                    67         0.726   0.815   11    -4.969     1
# 2                    70         0.675   0.931    1    -3.432     0
# 3                    60         0.718   0.930    7    -3.778     1
# 4                    69         0.650   0.833    1    -4.672     1
# ...                 ...           ...     ...  ...       ...   ...
# 32828                42         0.428   0.922    2    -1.814     1
# 32829                20         0.522   0.786    0    -4.462     1
# 32830                14         0.529   0.821    6    -4.899     0
# 32831                15         0.626   0.888    2    -3.361     1
# 32832                27         0.603   0.884    5    -4.571     0
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 0           0.0583      0.102000          0.000000    0.0653   0.5180
# 1           0.0373      0.072400          0.004210    0.3570   0.6930
# 2           0.0742      0.079400          0.000023    0.1100   0.6130
# 3           0.1020      0.028700          0.000009    0.2040   0.2770
# 4           0.0359      0.080300          0.000000    0.0833   0.7250
# ...            ...           ...               ...       ...      ...
# 32828       0.0936      0.076600          0.000000    0.0668   0.2100
# 32829       0.0420      0.001710          0.004270    0.3750   0.4000
# 32830       0.0481      0.108000          0.000001    0.1500   0.4360
# 32831       0.1090      0.007920          0.127000    0.3430   0.3080
# 32832       0.0385      0.000133          0.341000    0.7420   0.0894
#
#          tempo  duration_ms
# 0      122.036       194754
# 1       99.972       162600
# 2      124.008       176616
# 3      121.956       169093
# 4      123.976       189052
# ...        ...          ...
# 32828  128.170       204375
# 32829  128.041       353120
# 32830  127.989       210112
# 32831  128.008       367432
# 32832  127.984       337500
#
# [32833 rows x 13 columns]

# %%
# save it in a variable
numvalues_corr = numvalues.corr()

# %%
#setting the width and height for the plot
plt.figure(figsize=(10,8))
#creating a heatmap to check the correlations between attributes
sns.heatmap(round(numvalues_corr, 3), annot=True)
plt.title('Correlation between song attributes')
plt.show()

# %% [markdown]
# This hypothesis is wrong since danceability has nothing to do with the popularity of a song. This plot also shows that the other variables do not have much in common with the popularity since the values are low. The highest correlation for track popularity is the acousticness.
